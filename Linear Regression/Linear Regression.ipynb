# %% [markdown]
# # Steps
#
# ### Training
#
# initialize weight as zero
# initialize bias as zero
#
# ### Given a data point:
#
# predict = wx + b
#
# mse = sum((y - predict)^2) / n
#
# use gradient:
#
#     dw = sum(2.xi(predict - yi)) / n
#     db = sum(2(predict - yi)) / n
#
#     w = w - a . dw
#     b = b - a . db
#
#
#
# repeat n times

# %%
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
class LinearRegression:
    def __init__(self , learn_rate = 0.01 , epochs = 1000):
        self.learn_rate = learn_rate
        self.epochs = epochs
        self.w = None
        self.b = None
    def predict(self, x):
        return np.dot(x,self.w) + self.b
    def gradient(self, y_pred , x , y , n):
        dw = np.sum(2 * x.T @ (y_pred - y)) / n
        db = np.sum(2 * (y_pred - y)) / n
        self.w = self.w - self.learn_rate * dw
        self.b = self.b - self.learn_rate * db
        
    def MSE(self , y_pred , y):
        return np.mean(np.power((y - y_pred), 2))
    
    def fit(self,x , y):
        n_sample , n_features = x.shape
        self.w = np.zeros(n_features)
        self.b = 0
        for _ in range(self.epochs):
            y_predict = self.predict(x)
            loss = self.MSE(y_predict , y)
            self.gradient(y_predict,x,y , n_sample)

# %%
X, y = datasets.make_regression(n_samples=1000, n_features=1, noise=20, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)

# %%
predictions = lr.predict(X)

# %%
cmap = plt.get_cmap('viridis')
fig = plt.figure(figsize=(8,6))
m1 = plt.scatter(X_train, y_train, color=cmap(0.9), s=10)
m2 = plt.scatter(X_test, y_test, color=cmap(0.5), s=10)
plt.plot(X, predictions, color='black', linewidth=2, label='Prediction')
plt.show()

# %%
LR = LinearRegression()
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = LR.predict(X)

# %%
cmap = plt.get_cmap('viridis')
fig = plt.figure(figsize=(8,6))
m1 = plt.scatter(X_train, y_train, color=cmap(0.9), s=10)
m2 = plt.scatter(X_test, y_test, color=cmap(0.5), s=10)
plt.plot(X, prediction, color='black', linewidth=2, label='Prediction')
plt.show()
